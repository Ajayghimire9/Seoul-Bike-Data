# %% [markdown]
# # Bike Rental Prediction

# %% [markdown]
# Currently Rental bikes are introduced in many urban cities for the enhancement of mobility comfort. It is important to make the rental bike available and accessible to the public at the right time as it lessens the waiting time. Eventually, providing the city with a stable supply of rental bikes becomes a major concern. The crucial part is the prediction of bike count required at each hour for the stable supply of rental bikes.

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
import warnings
import statsmodels.api as sm
import os
warnings.filterwarnings("ignore")

wd = "C:/Users/lenwy/scm"
pd.set_option("display.max_rows", 100, "display.max_columns", 100)

# %%
df = pd.read_csv(os.path.join(wd,"Data/SeoulBikeData.csv"),encoding= 'unicode_escape',parse_dates=[0])

# %%
os.path.join(wd,"Data/SeoulBikeData.csv")
# Out:
# 'C:/Users/lenwy/scm\\Data/SeoulBikeData.csv'

# %% [markdown]
# Dataset Sample

# %%
df.head()
# Out:
#         Date  Rented Bike Count  Hour  Temperature(°C)  Humidity(%)  \
# 0 2017-01-12                254     0             -5.2           37
# 1 2017-01-12                204     1             -5.5           38
# 2 2017-01-12                173     2             -6.0           39
# 3 2017-01-12                107     3             -6.2           40
# 4 2017-01-12                 78     4             -6.0           36
#
#    Wind speed (m/s)  Visibility (10m)  Dew point temperature(°C)  \
# 0               2.2              2000                      -17.6
# 1               0.8              2000                      -17.6
# 2               1.0              2000                      -17.7
# 3               0.9              2000                      -17.6
# 4               2.3              2000                      -18.6
#
#    Solar Radiation (MJ/m2)  Rainfall(mm)  Snowfall (cm) Seasons     Holiday  \
# 0                      0.0           0.0            0.0  Winter  No Holiday
# 1                      0.0           0.0            0.0  Winter  No Holiday
# 2                      0.0           0.0            0.0  Winter  No Holiday
# 3                      0.0           0.0            0.0  Winter  No Holiday
# 4                      0.0           0.0            0.0  Winter  No Holiday
#
#   Functioning Day
# 0             Yes
# 1             Yes
# 2             Yes
# 3             Yes
# 4             Yes

# %% [markdown]
# Below we can see that :
#
# One feature is in Date type.
#
# Four Features are in integer data types.
#
# Six Features are in float data types.
#
# Three Features are in object data types

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8760 entries, 0 to 8759
# Data columns (total 14 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Date                       8760 non-null   datetime64[ns]
#  1   Rented Bike Count          8760 non-null   int64
#  2   Hour                       8760 non-null   int64
#  3   Temperature(°C)            8760 non-null   float64
#  4   Humidity(%)                8760 non-null   int64
#  5   Wind speed (m/s)           8760 non-null   float64
#  6   Visibility (10m)           8760 non-null   int64
#  7   Dew point temperature(°C)  8760 non-null   float64
#  8   Solar Radiation (MJ/m2)    8760 non-null   float64
#  9   Rainfall(mm)               8760 non-null   float64
#  10  Snowfall (cm)              8760 non-null   float64
#  11  Seasons                    8760 non-null   object
#  12  Holiday                    8760 non-null   object
#  13  Functioning Day            8760 non-null   object
# dtypes: datetime64[ns](1), float64(6), int64(4), object(3)
# memory usage: 958.2+ KB

# %%
df=df.astype({'Rented Bike Count':'float','Hour':'object'})

# %%
df=df.rename(columns={'Temperature(°C)':'Temperature',
                      'Humidity(%)':'Humidity',
                      'Rainfall(mm)':'Rainfall',
                      'Snowfall (cm)':'Snowfall',
                      'Wind speed (m/s)':'Wind speed',
                      'Visibility (10m)':'Visibility',
                      'Solar Radiation (MJ/m2)':'Radiation',
                      'Dew point temperature(°C)':'Dew point temperature'})

# %% [markdown]
# Different Statistics
#
# Measures of Frequency :- Count, Percent, Frequency.
#
# Measures of Central Tendency :- Mean, Median, and Mode.
#
# Measures of Dispersion or Variation:- Range(min,max),Variance, Standard Deviation.
#
# Measures of Position :- Percentile Ranks, Quartile Ranks.

# %%
df.describe()
# Out:
#        Rented Bike Count         Hour  Temperature(°C)  Humidity(%)  \
# count        8760.000000  8760.000000      8760.000000  8760.000000
# mean          704.602055    11.500000        12.882922    58.226256
# std           644.997468     6.922582        11.944825    20.362413
# min             0.000000     0.000000       -17.800000     0.000000
# 25%           191.000000     5.750000         3.500000    42.000000
# 50%           504.500000    11.500000        13.700000    57.000000
# 75%          1065.250000    17.250000        22.500000    74.000000
# max          3556.000000    23.000000        39.400000    98.000000
#
#        Wind speed (m/s)  Visibility (10m)  Dew point temperature(°C)  \
# count       8760.000000       8760.000000                8760.000000
# mean           1.724909       1436.825799                   4.073813
# std            1.036300        608.298712                  13.060369
# min            0.000000         27.000000                 -30.600000
# 25%            0.900000        940.000000                  -4.700000
# 50%            1.500000       1698.000000                   5.100000
# 75%            2.300000       2000.000000                  14.800000
# max            7.400000       2000.000000                  27.200000
#
#        Solar Radiation (MJ/m2)  Rainfall(mm)  Snowfall (cm)
# count              8760.000000   8760.000000    8760.000000
# mean                  0.569111      0.148687       0.075068
# std                   0.868746      1.128193       0.436746
# min                   0.000000      0.000000       0.000000
# 25%                   0.000000      0.000000       0.000000
# 50%                   0.010000      0.000000       0.000000
# 75%                   0.930000      0.000000       0.000000
# max                   3.520000     35.000000       8.800000

# %%
df.nunique().sort_values(ascending=True)
# Out:
# Holiday                         2
# Functioning Day                 2
# Seasons                         4
# Hour                           24
# Snowfall (cm)                  51
# Rainfall(mm)                   61
# Wind speed (m/s)               65
# Humidity(%)                    90
# Solar Radiation (MJ/m2)       345
# Date                          365
# Temperature(°C)               546
# Dew point temperature(°C)     556
# Visibility (10m)             1789
# Rented Bike Count            2166
# dtype: int64

# %% [markdown]
# No missing values in our dataset, so no treating of null or missing values required

# %%
df.isnull().sum()
# Out:
# Date                         0
# Rented Bike Count            0
# Hour                         0
# Temperature(°C)              0
# Humidity(%)                  0
# Wind speed (m/s)             0
# Visibility (10m)             0
# Dew point temperature(°C)    0
# Solar Radiation (MJ/m2)      0
# Rainfall(mm)                 0
# Snowfall (cm)                0
# Seasons                      0
# Holiday                      0
# Functioning Day              0
# dtype: int64

# %% [markdown]
# On the graphs below we can see how each continuous variable is at each hour of the day.
#
# *Data Distribution at each hour*

# %%
plt.figure(figsize=(18, 18))
for i, col in enumerate(df.select_dtypes(include=['float64','int']).columns):
    plt.rcParams['axes.facecolor'] = 'black'
    ax = plt.subplot(4,3, i+1)
    sns.barplot(data=df,x='Hour', y=col, ax=ax,edgecolor="black",palette='viridis_r')
plt.suptitle('Data distribution of continuous variables')
plt.tight_layout()

# %% [markdown]
# Skewed Distribution of each variable

# %%
plt.figure(figsize=(12, 12))
for i, col in enumerate(df.select_dtypes(include=['float64','int64']).columns):
    plt.rcParams['axes.facecolor'] = 'black'
    ax = plt.subplot(5,2, i+1)
    sns.histplot(data=df, x=col, ax=ax,color='red',kde=True)
plt.suptitle('Data distribution of continuous variables')
plt.tight_layout()

# %% [markdown]
# The Above graphs show how different variables show positive and negative skewness

# %%
plt.figure(figsize=(18, 18))
for i, col in enumerate(df.select_dtypes(include=['float64','int64']).columns):
    plt.rcParams['axes.facecolor'] = 'black'
    ax = plt.subplot(5,2, i+1)
    sns.boxplot(data=df, x=col, ax=ax,color='blue')
plt.suptitle('Box Plot of continuous variables')
plt.tight_layout()

# %%
var=list(df.select_dtypes(include=['float64','int64']).columns)

# %%
from sklearn.preprocessing import PowerTransformer
sc_X=PowerTransformer(method = 'yeo-johnson')
df[var]=sc_X.fit_transform(df[var])

# %%
plt.figure(figsize=(18, 18))
for i, col in enumerate(df.select_dtypes(include=['float64','int64']).columns):
    plt.rcParams['axes.facecolor'] = 'black'
    ax = plt.subplot(5,2, i+1)
    sns.histplot(data=df, x=col, ax=ax,color='red',kde=True)
plt.suptitle('Data distribution of continuous variables')
plt.tight_layout()

# %%
plt.figure(figsize=(18, 18))
for i, col in enumerate(df.select_dtypes(include=['float64','int64']).columns):
    plt.rcParams['axes.facecolor'] = 'black'
    ax = plt.subplot(5,2, i+1)
    sns.boxplot(data=df, x=col, ax=ax,color='blue')
plt.suptitle('Box Plot of continuous variables')
plt.tight_layout()

# %%
plt.figure(figsize=(8,8))
sns.heatmap(df.select_dtypes(include=['float']).corr(),annot=True,center = 0)
plt.show()

# %%
season_var=pd.crosstab(index=df['Seasons'],columns='% observations')
plt.pie(season_var['% observations'],labels=season_var['% observations'].index,autopct='%.0f%%')
plt.title('Seasons')
plt.show()

# %%
Functioning_Day_var=pd.crosstab(index=df['Functioning Day'],columns='% observations')
plt.pie(Functioning_Day_var['% observations'],labels=Functioning_Day_var['% observations'].index,autopct='%.0f%%')
plt.title('Functioning Day')
plt.show()

# %%
holiday_var=pd.crosstab(index=df['Holiday'],columns='% observations')
plt.pie(holiday_var['% observations'],labels=holiday_var['% observations'].index,autopct='%.0f%%')
plt.title('Holiday')
plt.show()

# %%
sns.barplot(x=season_var.index,y=season_var['% observations'])
plt.title('Seasons')
plt.show()

# %%
df=pd.get_dummies(df,columns=['Holiday','Seasons','Functioning Day','Hour'],drop_first=True)

# %%
X=df.iloc[:,2:]
y=df.iloc[:,1]

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor

def calc_vif(X):

    # Calculating VIF
    vif = pd.DataFrame()
    vif["variables"] = X.columns
    vif["VIF"] = [variance_inflation_factor(X.values, i) for i in range(X.shape[1])]

    return(vif)

# %%
calc_vif(X.select_dtypes(include=['float','int']))
# Out:
#                variables        VIF
# 0            Temperature  45.786458
# 1               Humidity  12.009217
# 2             Wind speed   1.232661
# 3             Visibility   1.559788
# 4  Dew point temperature  60.274115
# 5              Radiation   1.858131
# 6               Rainfall   1.195148
# 7               Snowfall   1.166736

# %%
#Dew Point Temperature is highly correlated .let's delete this variable and check the VIF score again.
del X['Dew point temperature']

# %%
calc_vif(X.select_dtypes(include=['float','int']))
#Each variable is within the range between 1 and 5.
# Out:
#      variables       VIF
# 0  Temperature  1.561902
# 1     Humidity  2.437890
# 2   Wind speed  1.232537
# 3   Visibility  1.496192
# 4    Radiation  1.827230
# 5     Rainfall  1.194817
# 6     Snowfall  1.162319

# %%
from sklearn.feature_selection import SelectKBest
from sklearn.feature_selection import f_regression#Correlation

# %%
fs = SelectKBest(score_func=f_regression, k='all')
fs.fit(X, y)
# Out:
# SelectKBest(k='all', score_func=<function f_regression at 0x00000294D9DB3D30>)

# %%
feature_contribution=(fs.scores_/sum(fs.scores_))*100

# %%
for i,j in enumerate(X.columns):
    print(f'{j} : {feature_contribution[i]:.2f}%')
plt.figure(figsize=(12,6))
sns.barplot(x=X.columns,y=fs.scores_)
plt.show()
# Out:
# Temperature : 24.19%
# Humidity : 3.52%
# Wind speed : 1.16%
# Visibility : 2.43%
# Radiation : 8.55%
# Rainfall : 5.65%
# Snowfall : 2.65%
# Holiday_No Holiday : 0.53%
# Seasons_Spring : 0.07%
# Seasons_Summer : 6.95%
# Seasons_Winter : 13.04%
# Functioning Day_Yes : 13.83%
# Hour_1 : 0.27%
# Hour_2 : 0.91%
# Hour_3 : 1.95%
# Hour_4 : 3.25%
# Hour_5 : 3.11%
# Hour_6 : 1.15%
# Hour_7 : 0.02%
# Hour_8 : 0.47%
# Hour_9 : 0.00%
# Hour_10 : 0.05%
# Hour_11 : 0.00%
# Hour_12 : 0.04%
# Hour_13 : 0.08%
# Hour_14 : 0.11%
# Hour_15 : 0.21%
# Hour_16 : 0.39%
# Hour_17 : 0.93%
# Hour_18 : 2.18%
# Hour_19 : 0.97%
# Hour_20 : 0.56%
# Hour_21 : 0.49%
# Hour_22 : 0.28%
# Hour_23 : 0.00%

# %%
from sklearn.model_selection import train_test_split

X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.30,random_state=0)

# %%
from sklearn.preprocessing import StandardScaler

sc=StandardScaler()
X_train=sc.fit_transform(X_train)
X_test=sc.transform(X_test)

# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score
from sklearn.metrics import mean_squared_error
from sklearn.preprocessing import PolynomialFeatures
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.ensemble import BaggingRegressor
from sklearn.ensemble import StackingRegressor
from sklearn.model_selection import cross_val_score
model_comparison={}

# %%
model=LinearRegression()
model.fit(X_train,y_train)
y_pred=model.predict(X_test)
print(f"Model R-Square : {r2_score(y_test,y_pred)*100:.2f}%")
print(f"Model MSE : {mean_squared_error(y_test,y_pred)*100:.2f}%")
accuracies = cross_val_score(estimator = model, X = X_train, y = y_train, cv = 5)
print("Cross Val Accuracy: {:.2f} %".format(accuracies.mean()*100))
print("Cross Val Standard Deviation: {:.2f} %".format(accuracies.std()*100))
model_comparison['Linear Regression']=[r2_score(y_test,y_pred),mean_squared_error(y_test,y_pred),(accuracies.mean()),(accuracies.std())]
# Out:
# Model R-Square : 80.76%
# Model MSE : 19.16%
# Cross Val Accuracy: 80.35 %
# Cross Val Standard Deviation: 0.59 %

# %%
import statsmodels.api as sm
lin_reg=sm.OLS(y_train,X_train).fit()
lin_reg.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:      Rented Bike Count   R-squared (uncentered):                   0.807
# Model:                            OLS   Adj. R-squared (uncentered):              0.805
# Method:                 Least Squares   F-statistic:                              726.5
# Date:                Sun, 20 Nov 2022   Prob (F-statistic):                        0.00
# Time:                        21:09:43   Log-Likelihood:                         -3668.0
# No. Observations:                6132   AIC:                                      7406.
# Df Residuals:                    6097   BIC:                                      7641.
# Df Model:                          35
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# x1             0.3607      0.013     27.283      0.000       0.335       0.387
# x2            -0.1188      0.010    -12.492      0.000      -0.137      -0.100
# x3            -0.0206      0.007     -3.046      0.002      -0.034      -0.007
# x4             0.0084      0.007      1.157      0.247      -0.006       0.023
# x5             0.2291      0.017     13.603      0.000       0.196       0.262
# x6            -0.2603      0.006    -40.988      0.000      -0.273      -0.248
# x7            -0.0006      0.006     -0.102      0.919      -0.013       0.012
# x8             0.0513      0.006      8.986      0.000       0.040       0.063
# x9            -0.1030      0.007    -13.836      0.000      -0.118      -0.088
# x10           -0.0957      0.009    -10.381      0.000      -0.114      -0.078
# x11           -0.2716      0.010    -25.983      0.000      -0.292      -0.251
# x12            0.4646      0.006     79.193      0.000       0.453       0.476
# x13           -0.0427      0.008     -5.447      0.000      -0.058      -0.027
# x14           -0.0908      0.008    -11.508      0.000      -0.106      -0.075
# x15           -0.1212      0.008    -15.453      0.000      -0.137      -0.106
# x16           -0.1727      0.008    -22.168      0.000      -0.188      -0.157
# x17           -0.1624      0.008    -20.873      0.000      -0.178      -0.147
# x18           -0.0758      0.008     -9.681      0.000      -0.091      -0.060
# x19            0.0035      0.008      0.438      0.661      -0.012       0.019
# x20            0.0594      0.008      7.047      0.000       0.043       0.076
# x21           -0.0377      0.009     -4.072      0.000      -0.056      -0.020
# x22           -0.1138      0.010    -11.567      0.000      -0.133      -0.095
# x23           -0.1130      0.010    -11.231      0.000      -0.133      -0.093
# x24           -0.0958      0.010     -9.428      0.000      -0.116      -0.076
# x25           -0.1002      0.010     -9.764      0.000      -0.120      -0.080
# x26           -0.0995      0.010     -9.707      0.000      -0.120      -0.079
# x27           -0.0798      0.010     -7.930      0.000      -0.100      -0.060
# x28           -0.0477      0.010     -4.886      0.000      -0.067      -0.029
# x29            0.0128      0.009      1.391      0.164      -0.005       0.031
# x30            0.1193      0.008     14.495      0.000       0.103       0.135
# x31            0.0908      0.008     11.289      0.000       0.075       0.107
# x32            0.0832      0.008     10.710      0.000       0.068       0.098
# x33            0.0975      0.008     12.277      0.000       0.082       0.113
# x34            0.0698      0.008      8.942      0.000       0.055       0.085
# x35            0.0129      0.008      1.675      0.094      -0.002       0.028
# ==============================================================================
# Omnibus:                      409.821   Durbin-Watson:                   1.973
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              872.074
# Skew:                          -0.445   Prob(JB):                    4.28e-190
# Kurtosis:                       4.619   Cond. No.                         9.45
# ==============================================================================
#
# Notes:
# [1] R² is computed without centering (uncentered) since the model does not contain a constant.
# [2] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
residuals = lin_reg.resid
fitted_value=lin_reg.fittedvalues

# %%
np.mean(residuals)
# Out:
# 0.010699177021444102

# %%
sm.qqplot(residuals,fit=True,line='45')
plt.title('Q-Q Plot')
plt.show()

# %%
plt.plot(y_train, [0]*len(y_train),c='r')
plt.title('Residuals Vs Fitted Plot')
plt.show()

# %%
poly_reg=PolynomialFeatures(degree=2)
model=LinearRegression()
model.fit(poly_reg.fit_transform(X_train),y_train)
y_pred=model.predict(poly_reg.fit_transform(X_test))
print(f"Model R-Square : {r2_score(y_test,y_pred)*100:.2f}%")
print(f"Model MSE : {mean_squared_error(y_test,y_pred)*100:.2f}%")
accuracies = cross_val_score(estimator = model, X = X_train, y = y_train, cv = 5)
print("Cross Val Accuracy: {:.2f} %".format(accuracies.mean()*100))
print("Cross Val Standard Deviation: {:.2f} %".format(accuracies.std()*100))
model_comparison['Polynomial Regression']=[r2_score(y_test,y_pred),mean_squared_error(y_test,y_pred),(accuracies.mean()),(accuracies.std())]
# Out:
# Model R-Square : 88.66%
# Model MSE : 11.29%
# Cross Val Accuracy: 80.35 %
# Cross Val Standard Deviation: 0.59 %

# %%
model=DecisionTreeRegressor()
model.fit(X_train,y_train)
y_pred=model.predict(X_test)
print(f"Model R-Square : {r2_score(y_test,y_pred)*100:.2f}%")
print(f"Model MSE : {mean_squared_error(y_test,y_pred)*100:.2f}%")
accuracies = cross_val_score(estimator = model, X = X_train, y = y_train, cv = 5)
print("Cross Val Accuracy: {:.2f} %".format(accuracies.mean()*100))
print("Cross Val Standard Deviation: {:.2f} %".format(accuracies.std()*100))
model_comparison['Decision Tree Regression']=[r2_score(y_test,y_pred),mean_squared_error(y_test,y_pred),(accuracies.mean()),(accuracies.std())]
# Out:
# Model R-Square : 79.64%
# Model MSE : 20.28%
# Cross Val Accuracy: 79.11 %
# Cross Val Standard Deviation: 1.41 %

# %%
model=RandomForestRegressor(n_estimators=10,random_state=0)
model.fit(X_train,y_train)
y_pred=model.predict(X_test)
print(f"Model R-Square : {r2_score(y_test,y_pred)*100:.2f}%")
print(f"Model MSE : {mean_squared_error(y_test,y_pred)*100:.2f}%")
accuracies = cross_val_score(estimator = model, X = X_train, y = y_train, cv = 5)
print("Cross Val Accuracy: {:.2f} %".format(accuracies.mean()*100))
print("Cross Val Standard Deviation: {:.2f} %".format(accuracies.std()*100))
model_comparison['Random forest Regression']=[r2_score(y_test,y_pred),mean_squared_error(y_test,y_pred),(accuracies.mean()),(accuracies.std())]
# Out:
# Model R-Square : 87.32%
# Model MSE : 12.63%
# Cross Val Accuracy: 88.21 %
# Cross Val Standard Deviation: 0.65 %

# %%
from sklearn.ensemble import BaggingRegressor
model= BaggingRegressor(RandomForestRegressor(n_estimators=10,random_state=0),random_state=0)
model.fit(X_train, y_train)
y_pred=model.predict(X_test)
print(f"Model R-Square : {r2_score(y_test,y_pred)*100:.2f}%")
print(f"Model MSE : {mean_squared_error(y_test,y_pred)*100:.2f}%")
accuracies = cross_val_score(estimator = model, X = X_train, y = y_train, cv = 5)
print("Cross Val Accuracy: {:.2f} %".format(accuracies.mean()*100))
print("Cross Val Standard Deviation: {:.2f} %".format(accuracies.std()*100))
model_comparison['Bagging Regressor']=[r2_score(y_test,y_pred),mean_squared_error(y_test,y_pred),(accuracies.mean()),(accuracies.std())]
# Out:
# Model R-Square : 88.42%
# Model MSE : 11.53%
# Cross Val Accuracy: 89.08 %
# Cross Val Standard Deviation: 0.66 %

# %%
estimators=[('linear regression',LinearRegression()),('Decision Tree',DecisionTreeRegressor()),('random forest',RandomForestRegressor(n_estimators=10,random_state=0)),('bagging',BaggingRegressor(RandomForestRegressor(n_estimators=10,random_state=0),random_state=0))]

# %%
model=StackingRegressor(estimators=estimators,final_estimator=LinearRegression(),passthrough=True)
model.fit(X_train, y_train)
y_pred=model.predict(X_test)
print(f"Model R-Square : {r2_score(y_test,y_pred)*100:.2f}%")
print(f"Model MSE : {mean_squared_error(y_test,y_pred)*100:.2f}%")
accuracies = cross_val_score(estimator = model, X = X_train, y = y_train, cv = 5)
print("Cross Val Accuracy: {:.2f} %".format(accuracies.mean()*100))
print("Cross Val Standard Deviation: {:.2f} %".format(accuracies.std()*100))
model_comparison['Stacking Regressor']=[r2_score(y_test,y_pred),mean_squared_error(y_test,y_pred),(accuracies.mean()),(accuracies.std())]
# Out:
# Model R-Square : 89.02%
# Model MSE : 10.93%
# Cross Val Accuracy: 89.73 %
# Cross Val Standard Deviation: 0.57 %

# %%
Model_com_df=pd.DataFrame(model_comparison).T
Model_com_df.columns=['R-Square','MSE','CV Accuracy','CV std']
Model_com_df=Model_com_df.sort_values(by='R-Square',ascending=False)
Model_com_df.style.format("{:.2%}").background_gradient(cmap='RdYlBu_r')
# Out:
# <style type="text/css">
# #T_b8db6_row0_col0, #T_b8db6_row0_col2, #T_b8db6_row5_col1, #T_b8db6_row5_col3 {
#   background-color: #a50026;
#   color: #f1f1f1;
# }
# #T_b8db6_row0_col1, #T_b8db6_row0_col3, #T_b8db6_row5_col0, #T_b8db6_row5_col2 {
#   background-color: #313695;
#   color: #f1f1f1;
# }
# #T_b8db6_row1_col0 {
#   background-color: #b71126;
#   color: #f1f1f1;
# }
# #T_b8db6_row1_col1 {
#   background-color: #384ca0;
#   color: #f1f1f1;
# }
# #T_b8db6_row1_col2, #T_b8db6_row4_col2 {
#   background-color: #4b7db8;
#   color: #f1f1f1;
# }
# #T_b8db6_row1_col3, #T_b8db6_row4_col3 {
#   background-color: #374a9f;
#   color: #f1f1f1;
# }
# #T_b8db6_row2_col0 {
#   background-color: #c41e27;
#   color: #f1f1f1;
# }
# #T_b8db6_row2_col1 {
#   background-color: #3e5ea8;
#   color: #f1f1f1;
# }
# #T_b8db6_row2_col2 {
#   background-color: #c21c27;
#   color: #f1f1f1;
# }
# #T_b8db6_row2_col3 {
#   background-color: #4878b6;
#   color: #f1f1f1;
# }
# #T_b8db6_row3_col0 {
#   background-color: #ee613e;
#   color: #f1f1f1;
# }
# #T_b8db6_row3_col1 {
#   background-color: #6ba2cb;
#   color: #f1f1f1;
# }
# #T_b8db6_row3_col2 {
#   background-color: #e34933;
#   color: #f1f1f1;
# }
# #T_b8db6_row3_col3 {
#   background-color: #4574b3;
#   color: #f1f1f1;
# }
# #T_b8db6_row4_col0 {
#   background-color: #4d7fb9;
#   color: #f1f1f1;
# }
# #T_b8db6_row4_col1 {
#   background-color: #dc3b2c;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_b8db6">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_b8db6_level0_col0" class="col_heading level0 col0" >R-Square</th>
#       <th id="T_b8db6_level0_col1" class="col_heading level0 col1" >MSE</th>
#       <th id="T_b8db6_level0_col2" class="col_heading level0 col2" >CV Accuracy</th>
#       <th id="T_b8db6_level0_col3" class="col_heading level0 col3" >CV std</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_b8db6_level0_row0" class="row_heading level0 row0" >Stacking Regressor</th>
#       <td id="T_b8db6_row0_col0" class="data row0 col0" >89.02%</td>
#       <td id="T_b8db6_row0_col1" class="data row0 col1" >10.93%</td>
#       <td id="T_b8db6_row0_col2" class="data row0 col2" >89.73%</td>
#       <td id="T_b8db6_row0_col3" class="data row0 col3" >0.57%</td>
#     </tr>
#     <tr>
#       <th id="T_b8db6_level0_row1" class="row_heading level0 row1" >Polynomial Regression</th>
#       <td id="T_b8db6_row1_col0" class="data row1 col0" >88.66%</td>
#       <td id="T_b8db6_row1_col1" class="data row1 col1" >11.29%</td>
#       <td id="T_b8db6_row1_col2" class="data row1 col2" >80.35%</td>
#       <td id="T_b8db6_row1_col3" class="data row1 col3" >0.59%</td>
#     </tr>
#     <tr>
#       <th id="T_b8db6_level0_row2" class="row_heading level0 row2" >Bagging Regressor</th>
#       <td id="T_b8db6_row2_col0" class="data row2 col0" >88.42%</td>
#       <td id="T_b8db6_row2_col1" class="data row2 col1" >11.53%</td>
#       <td id="T_b8db6_row2_col2" class="data row2 col2" >89.08%</td>
#       <td id="T_b8db6_row2_col3" class="data row2 col3" >0.66%</td>
#     </tr>
#     <tr>
#       <th id="T_b8db6_level0_row3" class="row_heading level0 row3" >Random forest Regression</th>
#       <td id="T_b8db6_row3_col0" class="data row3 col0" >87.32%</td>
#       <td id="T_b8db6_row3_col1" class="data row3 col1" >12.63%</td>
#       <td id="T_b8db6_row3_col2" class="data row3 col2" >88.21%</td>
#       <td id="T_b8db6_row3_col3" class="data row3 col3" >0.65%</td>
#     </tr>
#     <tr>
#       <th id="T_b8db6_level0_row4" class="row_heading level0 row4" >Linear Regression</th>
#       <td id="T_b8db6_row4_col0" class="data row4 col0" >80.76%</td>
#       <td id="T_b8db6_row4_col1" class="data row4 col1" >19.16%</td>
#       <td id="T_b8db6_row4_col2" class="data row4 col2" >80.35%</td>
#       <td id="T_b8db6_row4_col3" class="data row4 col3" >0.59%</td>
#     </tr>
#     <tr>
#       <th id="T_b8db6_level0_row5" class="row_heading level0 row5" >Decision Tree Regression</th>
#       <td id="T_b8db6_row5_col0" class="data row5 col0" >79.64%</td>
#       <td id="T_b8db6_row5_col1" class="data row5 col1" >20.28%</td>
#       <td id="T_b8db6_row5_col2" class="data row5 col2" >79.11%</td>
#       <td id="T_b8db6_row5_col3" class="data row5 col3" >1.41%</td>
#     </tr>
#   </tbody>
# </table>

# %%
Model_com_df.style.highlight_max().set_caption("Maximum Score in each Column").format("{:.2%}")
# Out:
# <style type="text/css">
# #T_641e1_row0_col0, #T_641e1_row0_col2, #T_641e1_row5_col1, #T_641e1_row5_col3 {
#   background-color: yellow;
# }
# </style>
# <table id="T_641e1">
#   <caption>Maximum Score in each Column</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_641e1_level0_col0" class="col_heading level0 col0" >R-Square</th>
#       <th id="T_641e1_level0_col1" class="col_heading level0 col1" >MSE</th>
#       <th id="T_641e1_level0_col2" class="col_heading level0 col2" >CV Accuracy</th>
#       <th id="T_641e1_level0_col3" class="col_heading level0 col3" >CV std</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_641e1_level0_row0" class="row_heading level0 row0" >Stacking Regressor</th>
#       <td id="T_641e1_row0_col0" class="data row0 col0" >89.02%</td>
#       <td id="T_641e1_row0_col1" class="data row0 col1" >10.93%</td>
#       <td id="T_641e1_row0_col2" class="data row0 col2" >89.73%</td>
#       <td id="T_641e1_row0_col3" class="data row0 col3" >0.57%</td>
#     </tr>
#     <tr>
#       <th id="T_641e1_level0_row1" class="row_heading level0 row1" >Polynomial Regression</th>
#       <td id="T_641e1_row1_col0" class="data row1 col0" >88.66%</td>
#       <td id="T_641e1_row1_col1" class="data row1 col1" >11.29%</td>
#       <td id="T_641e1_row1_col2" class="data row1 col2" >80.35%</td>
#       <td id="T_641e1_row1_col3" class="data row1 col3" >0.59%</td>
#     </tr>
#     <tr>
#       <th id="T_641e1_level0_row2" class="row_heading level0 row2" >Bagging Regressor</th>
#       <td id="T_641e1_row2_col0" class="data row2 col0" >88.42%</td>
#       <td id="T_641e1_row2_col1" class="data row2 col1" >11.53%</td>
#       <td id="T_641e1_row2_col2" class="data row2 col2" >89.08%</td>
#       <td id="T_641e1_row2_col3" class="data row2 col3" >0.66%</td>
#     </tr>
#     <tr>
#       <th id="T_641e1_level0_row3" class="row_heading level0 row3" >Random forest Regression</th>
#       <td id="T_641e1_row3_col0" class="data row3 col0" >87.32%</td>
#       <td id="T_641e1_row3_col1" class="data row3 col1" >12.63%</td>
#       <td id="T_641e1_row3_col2" class="data row3 col2" >88.21%</td>
#       <td id="T_641e1_row3_col3" class="data row3 col3" >0.65%</td>
#     </tr>
#     <tr>
#       <th id="T_641e1_level0_row4" class="row_heading level0 row4" >Linear Regression</th>
#       <td id="T_641e1_row4_col0" class="data row4 col0" >80.76%</td>
#       <td id="T_641e1_row4_col1" class="data row4 col1" >19.16%</td>
#       <td id="T_641e1_row4_col2" class="data row4 col2" >80.35%</td>
#       <td id="T_641e1_row4_col3" class="data row4 col3" >0.59%</td>
#     </tr>
#     <tr>
#       <th id="T_641e1_level0_row5" class="row_heading level0 row5" >Decision Tree Regression</th>
#       <td id="T_641e1_row5_col0" class="data row5 col0" >79.64%</td>
#       <td id="T_641e1_row5_col1" class="data row5 col1" >20.28%</td>
#       <td id="T_641e1_row5_col2" class="data row5 col2" >79.11%</td>
#       <td id="T_641e1_row5_col3" class="data row5 col3" >1.41%</td>
#     </tr>
#   </tbody>
# </table>

# %%
Model_com_df.style.highlight_min().set_caption("Minimum Score in each Column").format("{:.2%}")
# Out:
# <style type="text/css">
# #T_d047e_row0_col1, #T_d047e_row0_col3, #T_d047e_row5_col0, #T_d047e_row5_col2 {
#   background-color: yellow;
# }
# </style>
# <table id="T_d047e">
#   <caption>Minimum Score in each Column</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_d047e_level0_col0" class="col_heading level0 col0" >R-Square</th>
#       <th id="T_d047e_level0_col1" class="col_heading level0 col1" >MSE</th>
#       <th id="T_d047e_level0_col2" class="col_heading level0 col2" >CV Accuracy</th>
#       <th id="T_d047e_level0_col3" class="col_heading level0 col3" >CV std</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_d047e_level0_row0" class="row_heading level0 row0" >Stacking Regressor</th>
#       <td id="T_d047e_row0_col0" class="data row0 col0" >89.02%</td>
#       <td id="T_d047e_row0_col1" class="data row0 col1" >10.93%</td>
#       <td id="T_d047e_row0_col2" class="data row0 col2" >89.73%</td>
#       <td id="T_d047e_row0_col3" class="data row0 col3" >0.57%</td>
#     </tr>
#     <tr>
#       <th id="T_d047e_level0_row1" class="row_heading level0 row1" >Polynomial Regression</th>
#       <td id="T_d047e_row1_col0" class="data row1 col0" >88.66%</td>
#       <td id="T_d047e_row1_col1" class="data row1 col1" >11.29%</td>
#       <td id="T_d047e_row1_col2" class="data row1 col2" >80.35%</td>
#       <td id="T_d047e_row1_col3" class="data row1 col3" >0.59%</td>
#     </tr>
#     <tr>
#       <th id="T_d047e_level0_row2" class="row_heading level0 row2" >Bagging Regressor</th>
#       <td id="T_d047e_row2_col0" class="data row2 col0" >88.42%</td>
#       <td id="T_d047e_row2_col1" class="data row2 col1" >11.53%</td>
#       <td id="T_d047e_row2_col2" class="data row2 col2" >89.08%</td>
#       <td id="T_d047e_row2_col3" class="data row2 col3" >0.66%</td>
#     </tr>
#     <tr>
#       <th id="T_d047e_level0_row3" class="row_heading level0 row3" >Random forest Regression</th>
#       <td id="T_d047e_row3_col0" class="data row3 col0" >87.32%</td>
#       <td id="T_d047e_row3_col1" class="data row3 col1" >12.63%</td>
#       <td id="T_d047e_row3_col2" class="data row3 col2" >88.21%</td>
#       <td id="T_d047e_row3_col3" class="data row3 col3" >0.65%</td>
#     </tr>
#     <tr>
#       <th id="T_d047e_level0_row4" class="row_heading level0 row4" >Linear Regression</th>
#       <td id="T_d047e_row4_col0" class="data row4 col0" >80.76%</td>
#       <td id="T_d047e_row4_col1" class="data row4 col1" >19.16%</td>
#       <td id="T_d047e_row4_col2" class="data row4 col2" >80.35%</td>
#       <td id="T_d047e_row4_col3" class="data row4 col3" >0.59%</td>
#     </tr>
#     <tr>
#       <th id="T_d047e_level0_row5" class="row_heading level0 row5" >Decision Tree Regression</th>
#       <td id="T_d047e_row5_col0" class="data row5 col0" >79.64%</td>
#       <td id="T_d047e_row5_col1" class="data row5 col1" >20.28%</td>
#       <td id="T_d047e_row5_col2" class="data row5 col2" >79.11%</td>
#       <td id="T_d047e_row5_col3" class="data row5 col3" >1.41%</td>
#     </tr>
#   </tbody>
# </table>
